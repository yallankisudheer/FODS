# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
df=pd.read_csv("D:\\Data Science\\Datasets\\housing_dataset.csv")
df
# Out:
#        ID      Price  Bedrooms  Bathrooms  Sqft_Living  Sqft_Lot  Floors  \
# 0       1  224835.71         4        3.0      1659.70   5141.78       1
# 1       2  193086.78         1        3.4      1564.66   3207.94       1
# 2       3  232384.43         3        1.3          NaN       NaN       2
# 3       4  276151.49         5        3.8      1177.98   6086.91       1
# 4       5  188292.33         3        3.4          NaN   3610.07       1
# ..    ...        ...       ...        ...          ...       ...     ...
# 995   996  185944.99         3        1.9          NaN   2305.58       1
# 996   997  289884.33         4        2.8       956.69   3879.75       2
# 997   998  232042.14         1        1.2      1051.94   4500.19       1
# 998   999  171441.05         3        1.5      1026.09       NaN       2
# 999  1000        NaN         2        3.1      1802.73   7036.91       2
#
#      Waterfront  View  Condition  Year_Built
# 0             1     1          2        1901
# ...

# %%
null_col=df.columns[df.isnull().any()]
null_col
# Out:
# Index(['Price', 'Bathrooms', 'Sqft_Living', 'Sqft_Lot'], dtype='object')

# %%
med_price=df['Price'].median()
df['Price'].fillna(med_price)
# Out:
# 0      224835.71
# 1      193086.78
# 2      232384.43
# 3      276151.49
# 4      188292.33
#          ...
# 995    185944.99
# 996    289884.33
# 997    232042.14
# 998    171441.05
# 999    202300.21
# Name: Price, Length: 1000, dtype: float64

# %%
mean_bath=df['Bathrooms'].mean()
df['Bathrooms'].fillna(mean_bath)
# Out:
# 0      3.0
# 1      3.4
# 2      1.3
# 3      3.8
# 4      3.4
#       ...
# 995    1.9
# 996    2.8
# 997    1.2
# 998    1.5
# 999    3.1
# Name: Bathrooms, Length: 1000, dtype: float64

# %%
df.dropna(inplace=True)

# %%
Q1=df['Price'].quantile(0.25)
Q2=df['Price'].quantile(0.75)

# %%
IQR=Q2-Q1
lb=Q1 - 1.5 * IQR
ub=Q2 + 1.5 *IQR

# %%
Outliers=df[(df['Price']>=lb) | (df['Price']<=ub)]
Outliers
# Out:
#       ID      Price  Bedrooms  Bathrooms  Sqft_Living  Sqft_Lot  Floors  \
# 0      1  224835.71         4        3.0      1659.70   5141.78       1
# 1      2  193086.78         1        3.4      1564.66   3207.94       1
# 3      4  276151.49         5        3.8      1177.98   6086.91       1
# 5      6  188293.15         3        2.9      2411.08   4944.34       2
# 6      7  278960.64         1        2.0       698.66   6094.28       2
# ..   ...        ...       ...        ...          ...       ...     ...
# 992  993  187641.13         1        2.7      1753.73   2778.89       2
# 993  994  165900.79         2        2.9      1917.88   2416.73       1
# 994  995  149919.00         4        2.6      1567.02   5546.30       1
# 996  997  289884.33         4        2.8       956.69   3879.75       2
# 997  998  232042.14         1        1.2      1051.94   4500.19       1
#
#      Waterfront  View  Condition  Year_Built
# 0             1     1          2        1901
# ...

# %%
scaler=MinMaxScaler()
df['Sqft_Living']=scaler.fit_transform(df[['Sqft_Living']])
df
# Out:
#       ID      Price  Bedrooms  Bathrooms  Sqft_Living  Sqft_Lot  Floors  \
# 0      1  224835.71         4        3.0     0.560613   5141.78       1
# 1      2  193086.78         1        3.4     0.528051   3207.94       1
# 3      4  276151.49         5        3.8     0.395565   6086.91       1
# 5      6  188293.15         3        2.9     0.818053   4944.34       2
# 6      7  278960.64         1        2.0     0.231339   6094.28       2
# ..   ...        ...       ...        ...          ...       ...     ...
# 992  993  187641.13         1        2.7     0.592830   2778.89       2
# 993  994  165900.79         2        2.9     0.649072   2416.73       1
# 994  995  149919.00         4        2.6     0.528859   5546.30       1
# 996  997  289884.33         4        2.8     0.319746   3879.75       2
# 997  998  232042.14         1        1.2     0.352381   4500.19       1
#
#      Waterfront  View  Condition  Year_Built
# 0             1     1          2        1901
# ...

# %%
df['Year_Built']=df['Year_Built'].astype(int)

# %%
df['Waterfront']=df['Waterfront'].apply(lambda x:1 if x=='Yes' else 0)

# %%
df.to_csv('Cleaned_dataset.csv',index=False)

# %%
df
# Out:
#       ID      Price  Bedrooms  Bathrooms  Sqft_Living  Sqft_Lot  Floors  \
# 0      1  224835.71         4        3.0     0.560613   5141.78       1
# 1      2  193086.78         1        3.4     0.528051   3207.94       1
# 3      4  276151.49         5        3.8     0.395565   6086.91       1
# 5      6  188293.15         3        2.9     0.818053   4944.34       2
# 6      7  278960.64         1        2.0     0.231339   6094.28       2
# ..   ...        ...       ...        ...          ...       ...     ...
# 992  993  187641.13         1        2.7     0.592830   2778.89       2
# 993  994  165900.79         2        2.9     0.649072   2416.73       1
# 994  995  149919.00         4        2.6     0.528859   5546.30       1
# 996  997  289884.33         4        2.8     0.319746   3879.75       2
# 997  998  232042.14         1        1.2     0.352381   4500.19       1
#
#      Waterfront  View  Condition  Year_Built
# 0             0     1          2        1901
# ...
